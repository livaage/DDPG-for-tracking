# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import sys
sys.path.append('../dataloader/')

from dataloader import DataLoader 
import keras

# %%
comp = pd.read_csv('../evaluation/comp_hits.csv')
quality = pd.read_csv('../evaluation/comp_hits_qualities.csv')
dl = DataLoader() 
hits, allowed_pids = dl.load_data_cms(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9297/2122203594.py in <module>
#       2 quality = pd.read_csv('../evaluation/comp_hits_qualities.csv')
#       3 dl = DataLoader()
# ----> 4 hits, allowed_pids = dl.load_data_cms(0)
#
# AttributeError: 'DataLoader' object has no attribute 'load_data_cms'

# %%
quality
# Out:
#            hit2_z     hit2_r  comp_hit_z  comp_hit_r   quality
# 0      139.800003  12.630226  174.399994   15.681581  0.133961
# 1      139.800003  12.630226  174.399994   15.681581  0.133961
# 2      174.399994  15.681581  201.158997   18.041164  0.163888
# 3      174.399994  15.681581  201.158997   18.041164  0.163888
# 4      174.399994  15.681581  201.158997   18.041164  0.163888
# ...           ...        ...         ...         ...       ...
# 38518  -24.799999   5.626792  -32.576000    6.151925 -5.942018
# 38519  -24.799999   5.626792  -32.576000    6.151925 -5.942018
# 38520   41.098999   4.580255   52.910999    6.321467 -1.947626
# 38521   41.098999   4.580255   52.910999    6.321467 -1.947626
# 38522  201.158997   9.737274  230.569000   11.275066 -5.315302
#
# [38523 rows x 5 columns]

# %%
merged = comp.join(quality,  lsuffix='_1', rsuffix='_2')

# %%
merged = merged.dropna()

# %%
hits[['z_2', 'r_2']] = hits.groupby('particle_id')[['z', 'r']].shift(-1).dropna()

# %%
double_merge = hits.merge(merged.rename({'hit2_z_1': 'z', 'hit2_r_1' :'r'}, axis='columns'))

# %%
agree = double_merge[(double_merge['z_2'] ==double_merge['comp_hit_z_1']) & (double_merge['r_2'] == double_merge['comp_hit_r_1'])]

# %%
len(agree)/(len(double_merge)/10)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_9297/2470214271.py in <module>
# ----> 1 len(agree)/(len(double_merge)/10)
#
# ZeroDivisionError: float division by zero

# %%
double_merge
# Out:
# Empty DataFrame
# Columns: [hit_id, x, y, z, r, layer_id, volume_id, module_id, phi, particle_id, pt, nhits, q, discrete_module_id, Unnamed: 0, unique_layer_id, z_2, diff_z, r_2, m, b, comp_hit_z_1, comp_hit_r_1, hit2_z_2, hit2_r_2, comp_hit_z_2, comp_hit_r_2, quality]
# Index: []
#
# [0 rows x 28 columns]

# %%
quality.hit2_r.value_counts()
# Out:
# 7.303267     495
# 5.258880     429
# 5.224966     429
# 6.111474     374
# 7.320758     374
#             ...
# 10.098383     11
# 3.996767      11
# 7.180122      11
# 7.136373      11
# 3.950813      11
# Name: hit2_r, Length: 1237, dtype: int64

# %%
merged.iloc[:11]
# Out:
#      particle_id    hit2_z_1   hit2_r_1  \
# 0   7.881319e+17  -60.250000   7.002734
# 1   7.881319e+17  -60.250000   7.002734
# 2   7.881319e+17  -60.250000   7.002734
# 3   7.881319e+17  -60.250000   7.002734
# 4   7.881319e+17  -60.250000   7.002734
# 5   7.881319e+17  -60.250000   7.002734
# 6   7.881319e+17  -60.250000   7.002734
# 7   7.881319e+17  -60.250000   7.002734
# 8   7.881319e+17  -60.250000   7.002734
# 9   7.881319e+17  -60.250000   7.002734
# 10  6.800494e+17 -254.550003  29.580128
#
#                                                     m  \
# 0                                -0.11618763436935205
# 1                                -0.11618763436935205
# 2                                -0.11618763436935205
# 3                                -0.11618763436935205
# 4                                -0.11618763436935205
# 5                                -0.11618763436935205
# 6                                -0.11618763436935205
# 7                                -0.11618763436935205
# 8                                -0.11618763436935205
# 9                                -0.11618763436935205
# 10  tf.Tensor(-0.11619862920240041, shape=(), dtyp...
#
#                                                     b  comp_hit_z_1  \
# 0                               0.0024287366745179284    -70.250000
# 1                               0.0024287366745179284   -110.199997
# 2                               0.0024287366745179284    -82.250000
# 3                               0.0024287366745179284   -130.199997
# 4                               0.0024287366745179284   -254.550003
# 5                               0.0024287366745179284    -69.750000
# 6                               0.0024287366745179284    -96.199997
# 7                               0.0024287366745179284    -81.750000
# 8                               0.0024287366745179284   -150.199997
# 9                               0.0024287366745179284   -214.550003
# 10  tf.Tensor(0.0017662979833517056, shape=(), dty...   -294.549988
#
#     comp_hit_r_1    hit2_z_2   hit2_r_2  comp_hit_z_2  comp_hit_r_2   quality
# 0       8.165700  -60.250000   7.002734    -70.250000      8.165700 -0.002823
# 1      12.805676  -60.250000   7.002734   -110.199997     12.805676  0.015146
# 2       9.557798  -60.250000   7.002734    -82.250000      9.557798  0.003022
# 3      15.135748  -60.250000   7.002734   -130.199997     15.135748  0.023392
# 4      29.580128  -60.250000   7.002734   -254.550003     29.580128  0.075206
# 5       8.110636  -60.250000   7.002734    -69.750000      8.110636 -0.003078
# 6      11.173598  -60.250000   7.002734    -96.199997     11.173598  0.009157
# 7       9.514124  -60.250000   7.002734    -81.750000      9.514124  0.002787
# 8      17.443451  -60.250000   7.002734   -150.199997     17.443451  0.031653
# 9      24.944431  -60.250000   7.002734   -214.550003     24.944431  0.058184
# 10     34.207714 -254.550003  29.580128   -294.549988     34.207714 -0.013495

# %%
merged.describe()
# Out:
#         particle_id       hit2_z_1       hit2_r_1   comp_hit_z_1  \
# count  1.932920e+05  193292.000000  193292.000000  193292.000000
# mean   4.200923e+17      43.761062      14.189856      61.778142
# std    2.129220e+17      45.853546      14.783791      76.109317
# min    4.505180e+15     -69.800003       3.317971    -295.549988
# 25%    3.107503e+17      13.914301       6.523355      20.900000
# 50%    4.368531e+17      27.000000      11.554938      69.800003
# 75%    5.899779e+17      81.750000      17.149580     129.750000
# max    8.151527e+17     109.750000     102.387398     295.549988
#
#         comp_hit_r_1       hit2_z_2       hit2_r_2   comp_hit_z_2  \
# count  193292.000000  193292.000000  193292.000000  193292.000000
# mean       30.492571      43.761062      14.189856      61.778142
# std        28.251517      45.853546      14.783791      76.109317
# min         4.851836     -69.800003       3.317971    -295.549988
# 25%         7.572295      13.914301       6.523355      20.900000
# 50%        17.190012      27.000000      11.554938      69.800003
# 75%        49.913956      81.750000      17.149580     129.750000
# max       102.534622     109.750000     102.387398     295.549988
#
#         comp_hit_r_2        quality
# count  193292.000000  193292.000000
# mean       30.492571      -2.722224
# std        28.251517       3.846493
# min         4.851836     -21.993180
# 25%         7.572295      -3.150656
# 50%        17.190012      -1.318088
# 75%        49.913956      -0.541968
# max       102.534622       0.014721

# %%
merged.iloc[:10].comp_hit_r_2.values
# Out:
# array([11.54135323, 11.72531605, 49.56609344, 11.66087723, 26.49073219,
#        26.52404785, 26.47735214, 26.47519302, 26.56677818, 26.45342445])

# %%
first = merged[merged['hit2_z_1']==-24.399999618530277].dropna()

# %%
#'comp_rs = np.unique(first.comp_hit_r_2)
#comp_rs = merged.iloc[:10].comp_hit_r_2.values
#for i in comp_rs: 
j = 0
for i in range(j, j+10): 
    hit2_r = merged.iloc[j].hit2_r_2
    comp_r = merged.iloc[i].comp_hit_r_1
    ex = merged[(merged['hit2_r_2']==hit2_r) & (merged['comp_hit_r_2']==comp_r)]
    #print(ex)
    plt.plot(range(len(ex)), ex.quality, label="yes")
    #print(comp_r)
    plt.show()
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
hits[hits['particle_id']==416]
# Out:
# Empty DataFrame
# Columns: [run, lumi, evt, nhit, hit_n, hit_id, x, y, z, particle_id, pdg_id, pt, eta, phi, sim_type, sim_id, sim_dxy_sig, sim_pt, sim_eta, sim_phi, volume_id, layer_id, module_id, r, unique_layer_ids, unique_layer_id, discrete_module_id]
# Index: []
#
# [0 rows x 27 columns]

# %%
ex = merged[merged['hit2_r_2']==4.991849422454834]

# %%
plt.plot(range(len(ex)), ex.quality)

# %%
p = hits[hits['particle_id']==-20750.0]

# %%
p.append(p)
# Out:
#                 run  lumi   evt    nhit   hit_n  hit_id         x         y  \
# entry subentry
# 0     46641       1    52  5102  286493  286493   44677  1.316711 -3.308324
#       46565       1    52  5102  286493  286493   44601  1.320554 -3.319735
#       50799       1    52  5102  286493  286493   48878  1.661175 -4.144069
#       59007       1    52  5102  286493  286493   57149  2.405114 -5.907001
#       63241       1    52  5102  286493  286493   61412  2.778896 -6.772751
#       63225       1    52  5102  286493  286493   61396  2.788306 -6.793437
#       67757       1    52  5102  286493  286493   65954  3.212962 -7.765092
#       46641       1    52  5102  286493  286493   44677  1.316711 -3.308324
#       46565       1    52  5102  286493  286493   44601  1.320554 -3.319735
#       50799       1    52  5102  286493  286493   48878  1.661175 -4.144069
#       59007       1    52  5102  286493  286493   57149  2.405114 -5.907001
#       63241       1    52  5102  286493  286493   61412  2.778896 -6.772751
#       63225       1    52  5102  286493  286493   61396  2.788306 -6.793437
#       67757       1    52  5102  286493  286493   65954  3.212962 -7.765092
#
#                          z  particle_id  ...    sim_pt   sim_eta   sim_phi  \
# entry subentry                           ...
# 0     46641    -109.656998       -20750  ...  2.138403 -4.146584 -1.200927
#       46565    -110.056999       -20750  ...  2.138403 -4.146584 -1.200927
#       50799    -140.199997       -20750  ...  2.138403 -4.146584 -1.200927
#       59007    -200.358994       -20750  ...  2.138403 -4.146584 -1.200927
#       63241    -230.169006       -20750  ...  2.138403 -4.146584 -1.200927
#       63225    -230.968994       -20750  ...  2.138403 -4.146584 -1.200927
#       67757    -264.399994       -20750  ...  2.138403 -4.146584 -1.200927
#       46641    -109.656998       -20750  ...  2.138403 -4.146584 -1.200927
#       46565    -110.056999       -20750  ...  2.138403 -4.146584 -1.200927
#       50799    -140.199997       -20750  ...  2.138403 -4.146584 -1.200927
#       59007    -200.358994       -20750  ...  2.138403 -4.146584 -1.200927
#       63241    -230.169006       -20750  ...  2.138403 -4.146584 -1.200927
#       63225    -230.968994       -20750  ...  2.138403 -4.146584 -1.200927
#       67757    -264.399994       -20750  ...  2.138403 -4.146584 -1.200927
#
#                 volume_id  layer_id  module_id         r  unique_layer_ids  \
# entry subentry
# 0     46641             1         7         17  3.560721                11
#       46565             1         7         16  3.572744                11
#       50799             1         8         17  4.464617                12
#       59007             1        10         17  6.377870                14
#       63241             1        11         17  7.320684                15
#       63225             1        11         16  7.343394                15
#       67757             1        12         17  8.403558                16
#       46641             1         7         17  3.560721                11
#       46565             1         7         16  3.572744                11
#       50799             1         8         17  4.464617                12
#       59007             1        10         17  6.377870                14
#       63241             1        11         17  7.320684                15
#       63225             1        11         16  7.343394                15
#       67757             1        12         17  8.403558                16
#
#                 unique_layer_id  discrete_module_id
# entry subentry
# 0     46641                  11               11117
#       46565                  11               11116
#       50799                  12               11217
#       59007                  14               11417
#       63241                  15               11517
#       63225                  15               11516
#       67757                  16               11617
#       46641                  11               11117
#       46565                  11               11116
#       50799                  12               11217
#       59007                  14               11417
#       63241                  15               11517
#       63225                  15               11516
#       67757                  16               11617
#
# [14 rows x 27 columns]

# %%
trues = []
falses = [] 

for i in range(2, len(p)-1): 
    row = p.iloc[i]
    print(row.r)
    m_one_hit = merged[merged['hit2_r_2']==row.r]
    print(m_one_hit)
    next_true_hit = p.iloc[i+1]
    true = len(m_one_hit[m_one_hit['comp_hit_r_2']==next_true_hit.r]) 
    false = len(m_one_hit) - true 
    trues.append(true)
    falses.append(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9297/1537538029.py in <module>
#       2 falses = []
#       3
# ----> 4 for i in range(2, len(p)-1):
#       5     row = p.iloc[i]
#       6     print(row.r)
#
# NameError: name 'p' is not defined

# %%
trues
# Out:
# [0, 0, 0, 0]

# %%
falses
# Out:
# [1650, 0, 0, 0]

# %%
quality
# Out:
#            hit2_z    hit2_r  comp_hit_z  comp_hit_r    quality
# 0      -31.775999  5.468029  -32.576000    5.635563   0.062193
# 1      -31.775999  5.468029  -40.699001    7.327832   0.076291
# 2      -31.775999  5.468029  -32.175999    5.560024   0.061495
# 3      -31.775999  5.468029  -41.098999    7.426084   0.076966
# 4      -31.775999  5.468029  -32.175999    5.541021   0.061493
# ...           ...       ...         ...         ...        ...
# 148633 -52.910999  9.950032  -66.307999   12.780613 -15.985365
# 148634 -52.910999  9.950032  -66.307999   12.774048 -15.985574
# 148635 -52.910999  9.950032  -66.307999   12.772175 -15.985631
# 148636 -52.910999  9.950032  -66.307999   12.780315 -15.985377
# 148637 -52.910999  9.950032  -66.307999   12.798138 -15.984826
#
# [148638 rows x 5 columns]

# %%
for pid in merged.particle_id: 
    p = merged[merged['particle_id']==pid]
# Out:
#          particle_id   hit2_z_1  hit2_r_1  \
# 0       4.368531e+17    4.92568  7.135254
# 1       4.368531e+17    4.92568  7.135254
# 2       4.368531e+17    4.92568  7.135254
# 3       4.368531e+17    4.92568  7.135254
# 4       4.368531e+17    4.92568  7.135254
# ...              ...        ...       ...
# 193287  5.179289e+17  109.75000  6.554595
# 193288  5.179289e+17  109.75000  6.554595
# 193289  5.179289e+17  109.75000  6.554595
# 193290  5.179289e+17  109.75000  6.554595
# 193291  5.179289e+17  109.75000  6.554595
#
#                                                         m  \
# 0                                      1.4645362723123903
# 1                                      1.4645362723123903
# 2                                      1.4645362723123903
# 3                                      1.4645362723123903
# 4                                      1.4645362723123903
# ...                                                   ...
# 193287  tf.Tensor(0.00017554419381277903, shape=(), dt...
# 193288  tf.Tensor(0.00017554419381277903, shape=(), dt...
# 193289  tf.Tensor(0.00017554419381277903, shape=(), dt...
# 193290  tf.Tensor(0.00017554419381277903, shape=(), dt...
# 193291  tf.Tensor(0.00017554419381277903, shape=(), dt...
#
#                                                         b  comp_hit_z_1  \
# 0                                    -0.07858335464466126      8.753930
# 1                                    -0.07858335464466126      8.286460
# 2                                    -0.07858335464466126     32.760002
# 3                                    -0.07858335464466126      9.128650
# 4                                    -0.07858335464466126     17.150000
# ...                                                   ...           ...
# 193287  tf.Tensor(6.535328541483198, shape=(), dtype=f...    150.199997
# 193288  tf.Tensor(6.535328541483198, shape=(), dtype=f...    129.800003
# 193289  tf.Tensor(6.535328541483198, shape=(), dtype=f...    149.800003
# 193290  tf.Tensor(6.535328541483198, shape=(), dtype=f...    150.199997
# 193291  tf.Tensor(6.535328541483198, shape=(), dtype=f...    150.199997
#
#         comp_hit_r_1   hit2_z_2  hit2_r_2  comp_hit_z_2  comp_hit_r_2  \
# 0          11.541353    4.92568  7.135254      8.753930     11.541353
# 1          11.725316    4.92568  7.135254      8.286460     11.725316
# 2          49.566093    4.92568  7.135254     32.760002     49.566093
# 3          11.660877    4.92568  7.135254      9.128650     11.660877
# 4          26.490732    4.92568  7.135254     17.150000     26.490732
# ...              ...        ...       ...           ...           ...
# 193287     11.794086  109.75000  6.554595    150.199997     11.794086
# 193288     11.796741  109.75000  6.554595    129.800003     11.796741
# 193289     11.799599  109.75000  6.554595    149.800003     11.799599
# 193290     11.804876  109.75000  6.554595    150.199997     11.804876
# 193291     11.813058  109.75000  6.554595    150.199997     11.813058
#
#          quality
# 0       0.001274
# 1       0.001312
# 2       0.005472
# 3       0.001277
# 4       0.002926
# ...          ...
# 193287 -5.349674
# 193288 -4.748296
# 193289 -5.337931
# 193290 -5.349753
# 193291 -5.349814
#
# [193292 rows x 12 columns]

# %%
merged[merged['particle_id']==4.3685308086511206e+17]
# Out:
#       particle_id  hit2_z_1  hit2_r_1                   m  \
# 0    4.368531e+17   4.92568  7.135254  1.4645362723123903
# 1    4.368531e+17   4.92568  7.135254  1.4645362723123903
# 2    4.368531e+17   4.92568  7.135254  1.4645362723123903
# 3    4.368531e+17   4.92568  7.135254  1.4645362723123903
# 4    4.368531e+17   4.92568  7.135254  1.4645362723123903
# ..            ...       ...       ...                 ...
# 995  4.368531e+17   4.92568  7.135254  1.4645362723123903
# 996  4.368531e+17   4.92568  7.135254  1.4645362723123903
# 997  4.368531e+17   4.92568  7.135254  1.4645362723123903
# 998  4.368531e+17   4.92568  7.135254  1.4645362723123903
# 999  4.368531e+17   4.92568  7.135254  1.4645362723123903
#
#                         b  comp_hit_z_1  comp_hit_r_1  hit2_z_2  hit2_r_2  \
# 0    -0.07858335464466126      8.753930     11.541353   4.92568  7.135254
# 1    -0.07858335464466126      8.286460     11.725316   4.92568  7.135254
# 2    -0.07858335464466126     32.760002     49.566093   4.92568  7.135254
# 3    -0.07858335464466126      9.128650     11.660877   4.92568  7.135254
# 4    -0.07858335464466126     17.150000     26.490732   4.92568  7.135254
# ..                    ...           ...           ...       ...       ...
# 995  -0.07858335464466126      5.732030     11.557475   4.92568  7.135254
# 996  -0.07858335464466126     15.800000     26.312290   4.92568  7.135254
# 997  -0.07858335464466126     22.580000     36.239403   4.92568  7.135254
# 998  -0.07858335464466126     10.299500     11.761606   4.92568  7.135254
# 999  -0.07858335464466126     20.060001     26.054684   4.92568  7.135254
#
#      comp_hit_z_2  comp_hit_r_2   quality
# 0        8.753930     11.541353  0.001274
# 1        8.286460     11.725316  0.001312
# 2       32.760002     49.566093  0.005472
# 3        9.128650     11.660877  0.001277
# 4       17.150000     26.490732  0.002926
# ..            ...           ...       ...
# 995      5.732030     11.557475  0.001349
# 996     15.800000     26.312290  0.002942
# 997     22.580000     36.239403  0.004029
# 998     10.299500     11.761606  0.001251
# 999     20.060001     26.054684  0.002838
#
# [1000 rows x 12 columns]

# %%
hits[hits['particle_id']==4.3685308086511206e+17]
# Out:
#        hit_id           x          y          z           r  layer_id  \
# 4058    17266    3.102010  -0.831924   2.246590    3.211629         2
# 19733   23115    6.918780  -1.744230   4.925680    7.135254         4
# 31055   28951   11.234100  -2.630160   7.939400   11.537884         6
# 34673   28969   11.411200  -2.663000   8.062710   11.717810         6
# 42674   33749   16.871000  -3.541350  11.854900   17.238672         8
# 49510   57601   26.098099  -4.452540  18.230000   26.475193         2
# 56618   62812   36.109001  -4.629760  25.100000   36.404594         4
# 60307   68110   49.507500  -3.575450  34.349998   49.636444         6
# 67021   73079   65.836700  -0.317097  45.820000   65.837463         8
# 69016   73078   66.464798  -0.143485  46.299999   66.464951         8
# 71591   86336   81.813400   5.281590  58.020000   81.983696         2
# 75713   91119  100.790001  15.479300  72.639999  101.971725         4
#
#        volume_id  module_id       phi         particle_id        pt  nhits  q  \
# 4058           8        120 -0.262023  436853080865112064  0.737587     12 -1
# 19733          8        239 -0.246955  436853080865112064  0.737587     12 -1
# 31055          8        440 -0.229981  436853080865112064  0.737587     12 -1
# 34673          8        441 -0.229264  436853080865112064  0.737587     12 -1
# 42674          8        661 -0.206904  436853080865112064  0.737587     12 -1
# 49510         13        499 -0.168981  436853080865112064  0.737587     12 -1
# 56618         13        699 -0.127520  436853080865112064  0.737587     12 -1
# 60307         13       1053 -0.072095  436853080865112064  0.737587     12 -1
# 67021         13       1480 -0.004816  436853080865112064  0.737587     12 -1
# 69016         13       1479 -0.002159  436853080865112064  0.737587     12 -1
# 71591         17       1982  0.064467  436853080865112064  0.737587     12 -1
# 75713         17       2664  0.152389  436853080865112064  0.737587     12 -1
#
#        discrete_module_id  Unnamed: 0  unique_layer_id        z_2     diff_z
# 4058                  875           0              1.0   4.925680   2.679090
# 19733                1218           1              2.0   7.939400   3.013720
# 31055                1867           2              3.0   8.062710   0.123310
# 34673                1868           2              3.0  11.854900   3.792191
# 42674                2816           3              4.0  18.230000   6.375099
# 49510                5522           7              5.0  25.100000   6.870001
# 56618                6562           8              6.0  34.349998   9.249998
# 60307                8092           9              7.0  45.820000  11.470001
# 67021               10157          10              8.0  46.299999   0.480000
# 69016               10156          10              8.0  58.020000  11.720001
# 71591               14409          14              9.0  72.639999  14.619999
# 75713               17611          15             10.0        NaN        NaN

# %%
agree = double_merge[(double_merge['z_2'] ==double_merge['comp_hit_z_1']) & (double_merge['r_2'] == double_merge['comp_hit_r_1'])]
agree['is_true'] = np.ones(len(agree))
# Out:
# /home/lhv14/anaconda3/envs/garage/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
disagree = double_merge[(double_merge['z_2'] !=double_merge['comp_hit_z_1']) | (double_merge['r_2'] != double_merge['comp_hit_r_1'])]
disagree['is_true'] = np.zeros(len(disagree))
# Out:
# /home/lhv14/anaconda3/envs/garage/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.model_selection import train_test_split 

from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2022-10-10 14:48:11.265311: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/lhv14/.mujoco/mujoco210/bin
# 2022-10-10 14:48:11.265333: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
prepped = pd.concat([disagree,agree], axis=0)
#necessary because of replay 
predded = prepped.drop_duplicates() 
x_train, x_test, y_train, y_test = train_test_split(prepped[['r', 'z', 'comp_hit_z_1', 'comp_hit_r_1']], prepped['is_true'].values, train_size=0.7)

# %%
#I'm now going to define my neural net in a sequence of layers 
model = Sequential()
#our first layer! 20  is the number of neurons
model.add(Dense(100, input_dim=4, activation='relu'))
#input dimension is only specifiede in first layer
#for most cases, unless it's an output layer, relu is good 
#model.add(Dense(15, activation='relu'))
#in Keras in a regression, the number of neurons in the output layer is always 1
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#for a rgression, rmsprop is usually quite good 
#optimizer = keras.optimizers.rmsprop(learning_rate=0.001)
model.compile(loss='binary_crossentropy',metrics=['accuracy'], )
#epochs is how many times is all of the data going to go through the neural net
#batch_size is how many rows of the data to consider at any one time - but all of the data 
#will be used in one epoch 

#batch_size is usually set in powers of two 
model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 4560/4560 [==============================] - 7s 1ms/step - loss: 0.1328 - accuracy: 0.9675
# Epoch 2/100
# 2117/4560 [============>.................] - ETA: 3s - loss: 0.1113 - accuracy: 0.9714
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9297/3452121601.py in <module>
#       7
#       8 #batch_size is usually set in powers of two
# ----> 9 model.fit(x_train, y_train, epochs=100, batch_size=32)
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     510               attrs=attrs,
#     511               ctx=ctx,
# --> 512               cancellation_manager=cancellation_manager)
#     513       # Replace empty list with None
#     514       outputs = outputs or None
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __exit__(self, typ, exc, tb)
#     214     pass
#     215
# --> 216   def __exit__(self, typ, exc, tb):
#     217     if not exc or not isinstance(exc, errors.OpError):
#     218       return False
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import accuracy_score

preds = model.predict(x_test)

accuracy_test = accuracy_score(y_test, np.round(preds))

preds_train = model.predict(x_train)
accuracy_train = accuracy_score(y_train, np.round(preds_train))

print('test :', accuracy_test, 'train: ', accuracy_train)
# Out:
# test : 0.97319515081726 train:  0.9712871762181873

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(y_train, np.round(preds_train)).ravel()

# %%
fn
# Out:
# 4189

# %%
sum(np.round(y_train))
# Out:
# 4189.0

# %%
np.mean(agree.quality)
# Out:
# -0.19356639781724466

# %%
np.mean(disagree.quality)
# Out:
# -1.5036581669476303

# %%
agree#
# Out:
#         hit_id          x          y          z           r  layer_id  \
# 1530      7881  -0.955128   3.122490 -82.250000    3.265305        10
# 3135     41599  -1.498260   3.166350  82.250000    3.502935         6
# 3141     38640   3.282000  -1.275560  69.800003    3.521161         4
# 3256      8106  -2.547410   2.455150 -81.750000    3.537946        10
# 3261      7804  -1.497930   3.208660 -81.750000    3.541087        10
# ...        ...        ...        ...        ...         ...       ...
# 206029   91018 -88.064003 -51.590504  76.959999  102.062965         4
# 206039   91018 -88.064003 -51.590504  76.959999  102.062965         4
# 206049   91018 -88.064003 -51.590504  76.959999  102.062965         4
# 206059   91018 -88.064003 -51.590504  76.959999  102.062965         4
# 206069   91018 -88.064003 -51.590504  76.959999  102.062965         4
#
#         volume_id  module_id       phi         particle_id  ...  \
# 1530            7         87  1.867645  364792806767591424  ...
# 3135            9         87  2.012760  292738167667163136  ...
# 3141            9         47 -0.370687  747607914784489472  ...
# 3256            7         96  2.374635  193655402452221952  ...
# 3261            7         85  2.007565  207169431149740032  ...
# ...           ...        ...       ...                 ...  ...
# 206029         17       2597 -2.611658    4510815172427776  ...
# 206039         17       2597 -2.611658    4510815172427776  ...
# 206049         17       2597 -2.611658    4510815172427776  ...
# 206059         17       2597 -2.611658    4510815172427776  ...
# 206069         17       2597 -2.611658    4510815172427776  ...
#
#                                                         m  \
# 1530                                 -0.03984546661376953
# 3135                                  0.04288005828857422
# 3141                                 0.050546341010807114
# 3256                                 -0.04360497135840178
# 3261                                 -0.04331835252919282
# ...                                                   ...
# 206029  tf.Tensor(1.26114128447411, shape=(), dtype=fl...
# 206039  tf.Tensor(1.26114128447411, shape=(), dtype=fl...
# 206049  tf.Tensor(1.26114128447411, shape=(), dtype=fl...
# 206059  tf.Tensor(1.26114128447411, shape=(), dtype=fl...
# 206069  tf.Tensor(1.26114128447411, shape=(), dtype=fl...
#
#                                                         b  comp_hit_z_1  \
# 1530                                -0.011985063552856445    -95.750000
# 3135                                -0.023949384689331055     95.750000
# 3141                                -0.006973438984210212     70.199997
# 3256                                -0.026760899592436438    -82.199997
# 3261                               -0.0001886455249406893    -81.800003
# ...                                                   ...           ...
# 206029  tf.Tensor(5.005533294548243, shape=(), dtype=f...     77.540001
# 206039  tf.Tensor(5.005533294548243, shape=(), dtype=f...     77.540001
# 206049  tf.Tensor(5.005533294548243, shape=(), dtype=f...     77.540001
# 206059  tf.Tensor(5.005533294548243, shape=(), dtype=f...     77.540001
# 206069  tf.Tensor(5.005533294548243, shape=(), dtype=f...     77.540001
#
#         comp_hit_r_1   hit2_z_2    hit2_r_2  comp_hit_z_2  comp_hit_r_2  \
# 1530        3.802753 -82.250000    3.265305    -95.750000      3.802753
# 3135        4.077655  82.250000    3.502935     95.750000      4.077655
# 3141        3.541404  69.800003    3.521161     70.199997      3.541404
# 3256        3.559809 -81.750000    3.537946    -82.199997      3.559809
# 3261        3.542679 -81.750000    3.541087    -81.800003      3.542679
# ...              ...        ...         ...           ...           ...
# 206029    102.335724  76.959999  102.062965     77.540001    102.335724
# 206039    102.335724  76.959999  102.062965     77.540001    102.335724
# 206049    102.335724  76.959999  102.062965     77.540001    102.335724
# 206059    102.335724  76.959999  102.062965     77.540001    102.335724
# 206069    102.335724  76.959999  102.062965     77.540001    102.335724
#
#          quality is_true
# 1530    0.461687     1.0
# 3135   -0.734729     1.0
# 3141    0.866149     1.0
# 3256    0.174546     1.0
# 3261    1.155502     1.0
# ...          ...     ...
# 206029 -1.259105     1.0
# 206039 -1.181076     1.0
# 206049 -0.371133     1.0
# 206059 -0.371133     1.0
# 206069 -0.789082     1.0
#
# [5865 rows x 29 columns]

# %%
p = hits[hits['particle_id']==382808236069224448].reset_index()

# %%
position = p[p['hit_id']==42877].index[0]

p_wihtout_same_layer = p[p['unique_layer_id']!=21]

# %%
tmp_hit = p_wihtout_same_layer[p_wihtout_same_layer['r'] > 3.537194].iloc[0]

# %%
pd.concat([p, pd.DataFrame([tmp_hit])], axis=0)
# Out:
#       index   hit_id        x         y           z         r  layer_id  \
# 0       0.0  40897.0  3.01136 -0.224460   81.750000  3.019714       6.0
# 1      34.0  40930.0  3.02984 -0.225476   82.250000  3.038218       6.0
# 2    8207.0  42877.0  3.52687 -0.270048   95.750000  3.537194       8.0
# 3    8269.0  42912.0  3.54120 -0.270494   96.250000  3.551516       8.0
# 4    8279.0  42846.0  3.54268 -0.272039   96.199997  3.553109       8.0
# 5   10055.0  44570.0  4.03678 -0.315193  109.750000  4.049067      10.0
# 6   10122.0  44594.0  4.05256 -0.315512  110.250000  4.064824      10.0
# 7   10127.0  44543.0  4.05350 -0.312401  110.199997  4.065520      10.0
# 8   12636.0  46025.0  4.76538 -0.377551  129.750000  4.780313      12.0
# 9   12682.0  46005.0  4.77898 -0.378590  130.199997  4.793952      12.0
# 10  12687.0  46041.0  4.78036 -0.378604  130.250000  4.795329      12.0
# 11  14882.0  47223.0  5.49359 -0.444894  149.750000  5.511575      14.0
# 5   10055.0  44570.0  4.03678 -0.315193  109.750000  4.049067      10.0
#
#     volume_id  module_id       phi   particle_id        pt  nhits    q  \
# 0         9.0       52.0 -0.074400  3.828082e+17  0.677168   12.0  1.0
# 1         9.0       55.0 -0.074282  3.828082e+17  0.677168   12.0  1.0
# 2         9.0       52.0 -0.076420  3.828082e+17  0.677168   12.0  1.0
# 3         9.0       55.0 -0.076237  3.828082e+17  0.677168   12.0  1.0
# 4         9.0       50.0 -0.076639  3.828082e+17  0.677168   12.0  1.0
# 5         9.0       52.0 -0.077922  3.828082e+17  0.677168   12.0  1.0
# 6         9.0       55.0 -0.077698  3.828082e+17  0.677168   12.0  1.0
# 7         9.0       50.0 -0.076917  3.828082e+17  0.677168   12.0  1.0
# 8         9.0       52.0 -0.079063  3.828082e+17  0.677168   12.0  1.0
# 9         9.0       50.0 -0.079055  3.828082e+17  0.677168   12.0  1.0
# 10        9.0       55.0 -0.079035  3.828082e+17  0.677168   12.0  1.0
# 11        9.0       52.0 -0.080808  3.828082e+17  0.677168   12.0  1.0
# 5         9.0       52.0 -0.077922  3.828082e+17  0.677168   12.0  1.0
#
#     discrete_module_id  Unnamed: 0  unique_layer_id         z_2     diff_z  \
# 0               3515.0        30.0             20.0   82.250000   0.500000
# 1               3518.0        30.0             20.0   95.750000  13.500000
# 2               3623.0        31.0             21.0   96.250000   0.500000
# 3               3626.0        31.0             21.0   96.199997  -0.050003
# 4               3621.0        31.0             21.0  109.750000  13.550003
# 5               3731.0        34.0             22.0  110.250000   0.500000
# 6               3734.0        34.0             22.0  110.199997  -0.050003
# 7               3729.0        34.0             22.0  129.750000  19.550003
# 8               3839.0        33.0             23.0  130.199997   0.449997
# 9               3837.0        33.0             23.0  130.250000   0.050003
# 10              3842.0        33.0             23.0  149.750000  19.500000
# 11              3947.0        32.0             24.0         NaN        NaN
# 5               3731.0        34.0             22.0  110.250000   0.500000
#
#          r_2
# 0   3.038218
# 1   3.537194
# 2   3.551516
# 3   3.553109
# 4   4.049067
# 5   4.064824
# 6   4.065520
# 7   4.780313
# 8   4.793952
# 9   4.795329
# 10  5.511575
# 11       NaN
# 5   4.064824

# %%
pd.DataFrame([tmp_hit])
# Out:
#      index   hit_id        x         y       z         r  layer_id  volume_id  \
# 5  10055.0  44570.0  4.03678 -0.315193  109.75  4.049067      10.0        9.0
#
#    module_id       phi   particle_id        pt  nhits    q  \
# 5       52.0 -0.077922  3.828082e+17  0.677168   12.0  1.0
#
#    discrete_module_id  Unnamed: 0  unique_layer_id     z_2  diff_z       r_2
# 5              3731.0        34.0             22.0  110.25     0.5  4.064824
