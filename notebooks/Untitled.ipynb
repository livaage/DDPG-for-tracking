# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
hits = pd.read_hdf('/home/lhv14/iterativegnn/graph_construction/gnnfiles/ntuple_PU200_numEvent1000/ntuple_PU200_event0.h5')

# %%
for pid in [416, 526, 527, 597, 758, 759, 761, 907, 909]: 
    print(pid)
    p = hits[hits['particle_id']==pid]
    plt.plot(p.z, p.r, "kx")
    plt.show()
# Out:
# 416
# 526
# 527
# 597
# 758
# 759
# 761
# 907
# 909

# %%
good = [416, 526, 597, 759, 761, 907]
good_tracks = hits[hits['particle_id'].isin(good)]
good_tracks.pdg_id.value_counts()
# Out:
#  211     43
# -211     21
# -3222    12
# Name: pdg_id, dtype: int64

# %%
bad = [527, 758, 909]
bad_tracks = hits[hits['particle_id'].isin(bad)]
bad_tracks.pdg_id.value_counts()
# Out:
# 321    21
# 211    16
# 130     8
# Name: pdg_id, dtype: int64

# %%
out = pd.read_csv('../evaluation/garage_outputs.csv')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# /tmp/ipykernel_1015502/811153909.py in <module>
# ----> 1 out = pd.read_csv('../evaluation/garage_outputs.csv')
#
# ~/anaconda3/envs/garage/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# !ls ../evaluation
# Out:
# example_output_always_besthit.csv  garage_outputs.csv
# example_output_always_besthit.ods  track_visualisation.py

# %%
p = hits[hits['particle_id']==416]

# %%
p
# Out:
#     run  lumi   evt    nhit   hit_n  hit_id         x          y          z  \
# 76    1    89  8805  136545  136545     641  1.514243   2.374845 -16.072800
# 77    1    89  8805  136545  136545   24725  2.705725   4.194951 -24.400000
# 78    1    89  8805  136545  136545   24678  2.764010   4.284186 -24.799999
# 79    1    89  8805  136545  136545   23304  2.878195   4.456570 -25.600000
# 80    1    89  8805  136545  136545   28810  3.718941   5.714005 -31.375999
# 81    1    89  8805  136545  136545   28765  3.774443   5.799138 -31.775999
# 82    1    89  8805  136545  136545   27353  3.892431   5.973542 -32.576000
# 83    1    89  8805  136545  136545   33270  5.029653   7.641139 -40.299000
# 84    1    89  8805  136545  136545   34598  5.148115   7.811802 -41.098999
# 85    1    89  8805  136545  136545   40098  6.733172  10.080421 -51.710999
# 86    1    89  8805  136545  136545   40070  6.795594  10.166116 -52.111000
# ...
